# %%
#1) 10%    Up to $9,950
#2) 12%    $9,951 to $40,525
#3) 22%    $40,526 to $86,375
#4) 24%    $86,376 to $164,925
#5) 32%    $164,926 to $209,425
#6) 35%    $209,426 to $523,600
#7) 37%    $523,601 or more


def CalculateTaxes(income):
    global Deduction
    global totaltax
    if income <= Deduction:
        totaltax = 0
    else:
        income = income - Deduction
        rate = .10
        if income <= 9950:
            tax = income * rate
        else:
            tax = 9950 * rate
        print(str(tax))
        totaltax = tax + totaltax
        SecondBracket(income)
        ThirdBracket(income)
        FourthBracket(income)
        FifthBracket(income)
        SixthBracket(income)
        SeventhBracket(income)
################################################################

def SecondBracket(income):
    global totaltax
    previouslimit = 9950
    newlimit = 40525
    rate = .12
    if income <= previouslimit:
        tax = 0
    else:
        if income <= newlimit:
            tax = (income-previouslimit) * rate
        else:
            tax = (newlimit-previouslimit) * rate
    print(str(tax))
    totaltax = tax + totaltax
    
################################################################

def ThirdBracket(income):
    global totaltax
    previouslimit = 40525
    newlimit = 86375
    rate = .22
    if income <= previouslimit:
        tax = 0
    else:
        if income <= newlimit:
            tax = (income-previouslimit) * rate
        else:
            tax = (newlimit-previouslimit) * rate
    print(str(tax))
    totaltax = tax + totaltax
    
################################################################

def FourthBracket(income):
    global totaltax
    previouslimit = 86375
    newlimit = 164925
    rate = .24
    if income <= previouslimit:
        tax = 0
    else:
        if income <= newlimit:
            tax = (income-previouslimit) * rate
        else:
            tax = (newlimit-previouslimit) * rate
    print(str(tax))
    totaltax = tax + totaltax
    
################################################################

def FifthBracket(income):
    global totaltax
    previouslimit = 164925
    newlimit = 209425
    rate = .32
    if income <= previouslimit:
        tax = 0
    else:
        if income <= newlimit:
            tax = (income-previouslimit) * rate
        else:
            tax = (newlimit-previouslimit) * rate
    print(str(tax))
    totaltax = tax + totaltax
    
################################################################

def SixthBracket(income):
    global totaltax
    previouslimit = 209425
    newlimit = 523600
    rate = .35
    if income <= previouslimit:
        tax = 0
    else:
        if income <= newlimit:
            tax = (income-previouslimit) * rate
        else:
            tax = (newlimit-previouslimit) * rate
    print(str(tax))
    totaltax = tax + totaltax
    
################################################################

def SeventhBracket(income):
    global totaltax
    previouslimit = 523600
    newlimit = income
    rate = .37
    if income <= previouslimit:
        tax = 0
    else:
        if income <= newlimit:
            tax = (income-previouslimit) * rate
        else:
            tax = (newlimit-previouslimit) * rate
    print(str(tax))
    totaltax = tax + totaltax
    
################################################################
totaltax = 0    
income = float(input('Enter your salary please: '))
Deduction = 12000
CalculateTaxes(income)
#SecondBracket(income)
#ThirdBracket(income)
#FourthBracket(income)
#FifthBracket(income)
#SixthBracket(income)
#SeventhBracket(income)


#tax1 = FirstBracket(income)
#tax2 = SecondBracket(income)
#tax3 = ThirdBracket(income)
#tax4 = FourthBracket(income)
#tax5 = FifthBracket(income)
#tax6 = SixthBracket(income)
#tax7 = SeventhBracket(income)
#totaltax = tax1 + tax2 + tax3 + tax4 + tax5 + tax6 + tax7
print('\nYour total amount of taxes is $' + str(totaltax))
# Out:
# Enter your salary please: 23799.93
# 995.0
# 221.99160000000003
# 0
# 0
# 0
# 0
# 0
#
# Your total amount of taxes is $1216.9916
