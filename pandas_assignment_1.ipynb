# %%
# 1.) Download the cars.csv file under week 5

# 2.) Import the Pandas Python package into your Python environment using the following code: import pandas as pd

# 3.) Read the cars.csv into a pandas dataframe.

import pandas as pd

df = pd.read_csv('cars.csv')

df
# Out:
#        id first_name    last_name                        email           city  \
# 0       1      Elsey    MacEnelly      emacenelly0@storify.com    Baton Rouge
# 1       2        Web      Balmann             wbalmann1@un.org  Oklahoma City
# 2       3       Abey    Bernardet                          NaN       Lakeland
# 3       4      Adler  McGillecole      amcgillecole3@google.ru       Bethesda
# 4       5        Ola       Sparry            osparry4@usgs.gov        Spokane
# ..    ...        ...          ...                          ...            ...
# 995   996  Ethelbert       Escott        eescottrn@harvard.edu        Detroit
# 996   997       Yvon       Dugall    ydugallro@istockphoto.com       Palatine
# 997   998      Onfre         Life          oliferp@weather.com        Chicago
# 998   999   Vivianne   Grishukhin  vgrishukhinrq@wordpress.com      Worcester
# 999  1000      Lisha   Blackburne    lblackburnerr@skyrock.com        Detroit
#
# ...

# %%
# 1).  Extract the first 5 rows of the dataframe

df.head()
# Out:
#    id first_name    last_name                    email           city  \
# 0   1      Elsey    MacEnelly  emacenelly0@storify.com    Baton Rouge
# 1   2        Web      Balmann         wbalmann1@un.org  Oklahoma City
# 2   3       Abey    Bernardet                      NaN       Lakeland
# 3   4      Adler  McGillecole  amcgillecole3@google.ru       Bethesda
# 4   5        Ola       Sparry        osparry4@usgs.gov        Spokane
#
#         state car_make   car_model  car_model_year            car_vin
# 0   Louisiana  Pontiac     Sunfire            2005  JN1AV7ARXFM870659
# 1    Oklahoma  Hyundai      Accent            1998  4F2CY0C79BK404159
# 2     Florida    Lexus          ES            1993  SCFFDAAE1CG604846
# 3    Maryland    Buick  Rendezvous            2002  WAUVF78K39A869814
# 4  Washington   Nissan    Frontier            2001  1N6AA0CJ5DN998948

# %%
# 2). Extract the first 25 rows

df.head(25)
# Out:
#     id first_name    last_name                       email            city  \
# 0    1      Elsey    MacEnelly     emacenelly0@storify.com     Baton Rouge
# 1    2        Web      Balmann            wbalmann1@un.org   Oklahoma City
# 2    3       Abey    Bernardet                         NaN        Lakeland
# 3    4      Adler  McGillecole     amcgillecole3@google.ru        Bethesda
# 4    5        Ola       Sparry           osparry4@usgs.gov         Spokane
# 5    6     Nappie       Kytley           nkytley5@jugem.jp      Cincinnati
# 6    7      Alysa         Jopp        ajopp6@webeden.co.uk           Boise
# 7    8      Bruce      Guillet          bguillet7@fema.gov     Tallahassee
# 8    9  Annabella        Yurov              ayurov8@ed.gov        Prescott
# 9   10      Shane        Lemar        slemar9@hubpages.com      Des Moines
# 10  11      Irene     Domenico       idomenicoa@flavors.me      Washington
# ...

# %%
# 3). Extract the last 5 rows of the dataframe

df.tail()
# Out:
#        id first_name   last_name                        email       city  \
# 995   996  Ethelbert      Escott        eescottrn@harvard.edu    Detroit
# 996   997       Yvon      Dugall    ydugallro@istockphoto.com   Palatine
# 997   998      Onfre        Life          oliferp@weather.com    Chicago
# 998   999   Vivianne  Grishukhin  vgrishukhinrq@wordpress.com  Worcester
# 999  1000      Lisha  Blackburne    lblackburnerr@skyrock.com    Detroit
#
#              state    car_make    car_model  car_model_year            car_vin
# 995       Michigan   Chevrolet  Monte Carlo            1999  1N6AA0CC8DN240412
# 996       Illinois         GMC       Sonoma            2000  WAUJC68E24A901432
# 997       Illinois  Volkswagen        Jetta            1995  WAUDT48H05K333740
# 998  Massachusetts         Kia          Rio            2007  WAUBFAFL6AA707045
# 999       Michigan        Audi           S4            2013  SCFAD22343K508879

# %%
# 4.) Create a new column named 'full_name' by combining the first_name and last_name columns

df['full_name'] = df['first_name'] + ' ' + df['last_name']
df
# Out:
#        id first_name    last_name                        email           city  \
# 0       1      Elsey    MacEnelly      emacenelly0@storify.com    Baton Rouge
# 1       2        Web      Balmann             wbalmann1@un.org  Oklahoma City
# 2       3       Abey    Bernardet                          NaN       Lakeland
# 3       4      Adler  McGillecole      amcgillecole3@google.ru       Bethesda
# 4       5        Ola       Sparry            osparry4@usgs.gov        Spokane
# ..    ...        ...          ...                          ...            ...
# 995   996  Ethelbert       Escott        eescottrn@harvard.edu        Detroit
# 996   997       Yvon       Dugall    ydugallro@istockphoto.com       Palatine
# 997   998      Onfre         Life          oliferp@weather.com        Chicago
# 998   999   Vivianne   Grishukhin  vgrishukhinrq@wordpress.com      Worcester
# 999  1000      Lisha   Blackburne    lblackburnerr@skyrock.com        Detroit
#
# ...

# %%
# 5.) Rename the 'car_vin' column to 'vin_number'

df.rename(columns = {'car_vin': 'vin_number'}, inplace = True)
df
# Out:
#        id first_name    last_name                        email           city  \
# 0       1      Elsey    MacEnelly      emacenelly0@storify.com    Baton Rouge
# 1       2        Web      Balmann             wbalmann1@un.org  Oklahoma City
# 2       3       Abey    Bernardet                          NaN       Lakeland
# 3       4      Adler  McGillecole      amcgillecole3@google.ru       Bethesda
# 4       5        Ola       Sparry            osparry4@usgs.gov        Spokane
# ..    ...        ...          ...                          ...            ...
# 995   996  Ethelbert       Escott        eescottrn@harvard.edu        Detroit
# 996   997       Yvon       Dugall    ydugallro@istockphoto.com       Palatine
# 997   998      Onfre         Life          oliferp@weather.com        Chicago
# 998   999   Vivianne   Grishukhin  vgrishukhinrq@wordpress.com      Worcester
# 999  1000      Lisha   Blackburne    lblackburnerr@skyrock.com        Detroit
#
# ...

# %%
# 6). Find how many non null values are in each column

df.notnull().sum(axis = 0)
# Out:
# id                1000
# first_name        1000
# last_name         1000
# email              881
# city              1000
# state             1000
# car_make          1000
# car_model         1000
# car_model_year    1000
# vin_number        1000
# full_name         1000
# dtype: int64

# %%
# 7.) Clone the dataframe and rename your new dataframe 'df2'

df2 = df.copy()
df2
# Out:
#        id first_name    last_name                        email           city  \
# 0       1      Elsey    MacEnelly      emacenelly0@storify.com    Baton Rouge
# 1       2        Web      Balmann             wbalmann1@un.org  Oklahoma City
# 2       3       Abey    Bernardet                          NaN       Lakeland
# 3       4      Adler  McGillecole      amcgillecole3@google.ru       Bethesda
# 4       5        Ola       Sparry            osparry4@usgs.gov        Spokane
# ..    ...        ...          ...                          ...            ...
# 995   996  Ethelbert       Escott        eescottrn@harvard.edu        Detroit
# 996   997       Yvon       Dugall    ydugallro@istockphoto.com       Palatine
# 997   998      Onfre         Life          oliferp@weather.com        Chicago
# 998   999   Vivianne   Grishukhin  vgrishukhinrq@wordpress.com      Worcester
# 999  1000      Lisha   Blackburne    lblackburnerr@skyrock.com        Detroit
#
# ...

# %%
# 8.) Remove all missing values in df2

df3 = df2.dropna()

df3
# Out:
#        id first_name    last_name                        email           city  \
# 0       1      Elsey    MacEnelly      emacenelly0@storify.com    Baton Rouge
# 1       2        Web      Balmann             wbalmann1@un.org  Oklahoma City
# 3       4      Adler  McGillecole      amcgillecole3@google.ru       Bethesda
# 4       5        Ola       Sparry            osparry4@usgs.gov        Spokane
# 5       6     Nappie       Kytley            nkytley5@jugem.jp     Cincinnati
# ..    ...        ...          ...                          ...            ...
# 995   996  Ethelbert       Escott        eescottrn@harvard.edu        Detroit
# 996   997       Yvon       Dugall    ydugallro@istockphoto.com       Palatine
# 997   998      Onfre         Life          oliferp@weather.com        Chicago
# 998   999   Vivianne   Grishukhin  vgrishukhinrq@wordpress.com      Worcester
# 999  1000      Lisha   Blackburne    lblackburnerr@skyrock.com        Detroit
#
# ...
