# %%
# 1) 10%    Up to $9,950

# 2) 12%    $9,951 to $40,525

# 3) 22%    $40,526 to $86,375

# 4) 24%    $86,376 to $164,925

# 5) 32%    $164,926 to $209,425

# 6) 35%    $209,426 to $523,600

# 7) 37%    $523,601 or more

# %%
def first_bracket(income):
    rate= .10
    if income <= 9950:
        return income * rate
    else:
        tax = 9950 * rate
    print(str(tax))
    return tax
    
##########################################################

def second_bracket(income):
    previous_limit = 9950
    new_limit = 40525
    rate = .12
    
    if income <= 9950:
        tax = 0
    else:
        if income <= new_limit:
            tax = (income - previous_limit) * rate
        else: 
            tax = (new_limit - previous_limit) * rate
    print (str(tax))
    return tax
        
##########################################################

def third_bracket(income):
    previous_limit = 40525
    new_limit = 86375
    rate = .22
    
    if income <= previous_limit:
        tax = 0
    else:
        if income <= new_limit:
            tax = (income - previous_limit) * rate
        else: 
            tax = (new_limit - previous_limit) * rate
    print (str(tax))
    return tax

##########################################################

def fourth_bracket(income):
    previous_limit = 86375
    new_limit = 164925
    rate = .24
    
    if income <= previous_limit:
        tax = 0
    else:
        if income <= new_limit:
            tax = (income - previous_limit) * rate
        else: 
            tax = (new_limit - previous_limit) * rate
    print (str(tax))
    return tax

##########################################################

def fifth_bracket(income):
    previous_limit = 164925
    new_limit = 209425
    rate = .32
    
    if income <= previous_limit:
        tax = 0
    else:
        if income <= new_limit:
            tax = (income - previous_limit) * rate
        else: 
            tax = (new_limit - previous_limit) * rate
    print (str(tax))
    return tax

##########################################################

def sixth_bracket(income):
    previous_limit = 209425
    new_limit = 523600
    rate = .35
    
    if income <= previous_limit:
        tax = 0
    else:
        if income <= new_limit:
            tax = (income - previous_limit) * rate
        else: 
            tax = (new_limit - previous_limit) * rate
    print (str(tax))
    return tax

##########################################################

def seventh_bracket(income):
    previous_limit = 523600
    new_limit = income
    rate = .37
    
    if income <= previous_limit:
        tax = 0
    else:
        if income <= new_limit:
            tax = (income - previous_limit) * rate
        else: 
            tax = (new_limit - previous_limit) * rate
    print (str(tax))
    return tax

##########################################################
income = float(input('Enter your yearly salary: '))
tax1 = first_bracket(income)
tax2 = second_bracket(income)
tax3 = third_bracket(income)
tax4 = fourth_bracket(income)
tax5 = fifth_bracket(income)
tax6 = sixth_bracket(income)
tax7 = seventh_bracket(income)
total_tax = tax1 + tax2 + tax3 + tax4 + tax5 + tax6 + tax7
print('\nYour total tax amount for the year is: ' + str(total_tax) +'.')

##########################################################
# Out:
# Enter your yearly salary: 23799.93
# 995.0
# 1661.9916
# 0
# 0
# 0
# 0
# 0
#
# Your total tax amount for the year is: 2656.9916000000003.

# %%
def calculate_taxes(income):
    global deduction
    income = income - deduction
    global total_tax 
    rate= .10
    if income <= 9950:
        return income * rate
    else:
        tax = 9950 * rate
    print(str(tax))
    total_tax = tax + total_tax
    second_bracket(income)
    third_bracket(income)
    fourth_bracket(income)
    fifth_bracket(income)
    sixth_bracket(income)
    seventh_bracket(income)
    
##########################################################

def second_bracket(income):
    global total_tax 
    previous_limit = 9950
    new_limit = 40525
    rate = .12
    
    if income <= 9950:
        tax = 0
    else:
        if income <= new_limit:
            tax = (income - previous_limit) * rate
        else: 
            tax = (new_limit - previous_limit) * rate
    print (str(tax))
    return tax
        
##########################################################

def third_bracket(income):
    global total_tax 
    previous_limit = 40525
    new_limit = 86375
    rate = .22
    
    if income <= previous_limit:
        tax = 0
    else:
        if income <= new_limit:
            tax = (income - previous_limit) * rate
        else: 
            tax = (new_limit - previous_limit) * rate
    print (str(tax))
    return tax

##########################################################

def fourth_bracket(income):
    global total_tax 
    previous_limit = 86375
    new_limit = 164925
    rate = .24
    
    if income <= previous_limit:
        tax = 0
    else:
        if income <= new_limit:
            tax = (income - previous_limit) * rate
        else: 
            tax = (new_limit - previous_limit) * rate
    print (str(tax))
    return tax

##########################################################

def fifth_bracket(income):
    global total_tax 
    previous_limit = 164925
    new_limit = 209425
    rate = .32
    
    if income <= previous_limit:
        tax = 0
    else:
        if income <= new_limit:
            tax = (income - previous_limit) * rate
        else: 
            tax = (new_limit - previous_limit) * rate
    print (str(tax))
    return tax

##########################################################

def sixth_bracket(income):
    global total_tax 
    previous_limit = 209425
    new_limit = 523600
    rate = .35
    
    if income <= previous_limit:
        tax = 0
    else:
        if income <= new_limit:
            tax = (income - previous_limit) * rate
        else: 
            tax = (new_limit - previous_limit) * rate
    print (str(tax))
    return tax

##########################################################

def seventh_bracket(income):
    global total_tax 
    previous_limit = 523600
    new_limit = income
    rate = .37
    
    if income <= previous_limit:
        tax = 0
    else:
        if income <= new_limit:
            tax = (income - previous_limit) * rate
        else: 
            tax = (new_limit - previous_limit) * rate
    print (str(tax))
    total_tax = tax + total_tax

##########################################################
total_tax = 0
deduction = 12000
income = float(input('Enter your yearly salary: '))
calculate_taxes(income)
print('Total tax should be ' + str(total_tax) + '.')
##########################################################
# Out:
# Enter your yearly salary: 23799.93
# 995.0
# 221.99160000000003
# 0
# 0
# 0
# 0
# 0
# Total tax should be 995.0.
